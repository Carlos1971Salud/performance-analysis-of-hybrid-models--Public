# %% [markdown]
# <a href="https://colab.research.google.com/github/arianayunita/performance-analysis-of-hybrid-models-/blob/main/Visualisasi_Revisi_UPER_UTP_submit_to_E_Prime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dataset 1
#MAE

from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the folder path in Google Drive
# For example, saving to a folder named 'Figures' in 'My Drive'
folder_path = '/content/drive/My Drive/Figures/'

# Example plot (using your boxplot code or any other plot)

# Assuming df1, df2, ... df9 are already defined

df1 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN_FORECASTMae.xlsx')
df2 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM_FORECASTMae.xlsx')
df3 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU_FORECASTMae.xlsx')
df4 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN-LSTM_FORECASTMae.xlsx')
df5 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN-GRU_FORECASTMae.xlsx')
df6 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM-RNN_FORECASTMae.xlsx')
df7 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU-RNN_FORECASTMae.xlsx')
df8 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM-GRU_FORECASTMae.xlsx')
df9 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU-LSTM_FORECASTMae.xlsx')
df = pd.DataFrame()
df['RNN'] = sorted(df1[0])
df['LSTM'] = sorted(df2[0])
df['GRU'] = sorted(df3[0])
df['RNN_LSTM'] = sorted(df4[0])
df['RNN_GRU'] = sorted(df5[0])
df['LSTM_RNN'] = sorted(df6[0])
df['GRU_RNN'] = sorted(df7[0])
df['LSTM_GRU'] = sorted(df8[0])
df['GRU_LSTM'] = sorted(df9[0])

# Rename the columns
df.columns = ['RNN', 'LSTM', 'GRU', 'RNN-LSTM', 'RNN-GRU',
              'LSTM-RNN', 'GRU-RNN', 'LSTM-GRU', 'GRU-LSTM']
n = int(len(df) * 0.025)
df = df.iloc[n:-n]
data = df.copy()

# Boxplot customizations
fig, ax = plt.subplots(figsize=(20, 10))
plt.boxplot(
    data.values,
    labels=data.columns,
    boxprops=dict(color='blue'),
    whiskerprops=dict(color='red'),
    capprops=dict(color='purple'),
    flierprops=dict(markerfacecolor='black', marker='o', markersize=8),
    medianprops=dict(color='green')
)

# Enlarge the x-axis and y-axis labels
plt.xlabel('Models', fontsize=22)
plt.ylabel('Mean Average Error', fontsize=22)
plt.yticks(fontsize=20)

# Enlarge the labels for the boxplot
for tick in ax.get_xticklabels():
    tick.set_fontsize(20)
#    tick.set_fontweight('bold')

# Add the mean annotations
for i, column in enumerate(data.columns):
    mean = np.mean(data[column])
    plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom', color='black', fontsize=18)

plt.tight_layout()

# Step 3: Save the figure in Google Drive
plt.savefig(folder_path + 'Comparison_MAE_Dataset1.pdf', dpi=300)

# If you want to download the figure from Google Drive:
# files.download(folder_path + 'Comparison_MAE_Dataset1.pdf')

# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Dataset 1
#MAE

from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the folder path in Google Drive
# For example, saving to a folder named 'Figures' in 'My Drive'
folder_path = '/content/drive/My Drive/Figures/'

# Example plot (using your boxplot code or any other plot)

# Assuming df1, df2, ... df9 are already defined

df1 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN_FORECASTMpe.xlsx')
df2 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM_FORECASTMpe.xlsx')
df3 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU_FORECASTMpe.xlsx')
df4 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN-LSTM_FORECASTMpe.xlsx')
df5 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN-GRU_FORECASTMpe.xlsx')
df6 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM-RNN_FORECASTMpe.xlsx')
df7 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU-RNN_FORECASTMpe.xlsx')
df8 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM-GRU_FORECASTMpe.xlsx')
df9 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU-LSTM_FORECASTMpe.xlsx')
df = pd.DataFrame()
df['RNN'] = sorted(df1[0])
df['LSTM'] = sorted(df2[0])
df['GRU'] = sorted(df3[0])
df['RNN_LSTM'] = sorted(df4[0])
df['RNN_GRU'] = sorted(df5[0])
df['LSTM_RNN'] = sorted(df6[0])
df['GRU_RNN'] = sorted(df7[0])
df['LSTM_GRU'] = sorted(df8[0])
df['GRU_LSTM'] = sorted(df9[0])

# Rename the columns
df.columns = ['RNN', 'LSTM', 'GRU', 'RNN-LSTM', 'RNN-GRU',
              'LSTM-RNN', 'GRU-RNN', 'LSTM-GRU', 'GRU-LSTM']
n = int(len(df) * 0.025)
df = df.iloc[n:-n]
data = df.copy()

# Boxplot customizations
fig, ax = plt.subplots(figsize=(20, 10))
plt.boxplot(
    data.values,
    labels=data.columns,
    boxprops=dict(color='blue'),
    whiskerprops=dict(color='red'),
    capprops=dict(color='purple'),
    flierprops=dict(markerfacecolor='black', marker='o', markersize=8),
    medianprops=dict(color='green')
)

# Enlarge the x-axis and y-axis labels
plt.xlabel('Models', fontsize=22)
plt.ylabel('Mean Absolute Percentage Error', fontsize=22)
plt.yticks(fontsize=20)

# Enlarge the labels for the boxplot
for tick in ax.get_xticklabels():
    tick.set_fontsize(20)
#    tick.set_fontweight('bold')

# Add the mean annotations
for i, column in enumerate(data.columns):
    mean = np.mean(data[column])
    plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom', color='black', fontsize=18)

plt.tight_layout()

# Step 3: Save the figure in Google Drive
plt.savefig(folder_path + 'Comparison_MAPE_Dataset1.pdf', dpi=300)

# If you want to download the figure from Google Drive:
# files.download(folder_path + 'Comparison_MAE_Dataset1.pdf')

# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Dataset 1
#MAE

from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the folder path in Google Drive
# For example, saving to a folder named 'Figures' in 'My Drive'
folder_path = '/content/drive/My Drive/Figures/'

# Example plot (using your boxplot code or any other plot)

# Assuming df1, df2, ... df9 are already defined

df1 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN_FORECASTRMse.xlsx')
df2 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM_FORECASTRMse.xlsx')
df3 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU_FORECASTRMse.xlsx')
df4 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN-LSTM_FORECASTRMse.xlsx')
df5 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN-GRU_FORECASTRMse.xlsx')
df6 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM-RNN_FORECASTRMse.xlsx')
df7 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU-RNN_FORECASTRMse.xlsx')
df8 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM-GRU_FORECASTRMse.xlsx')
df9 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU-LSTM_FORECASTRMse.xlsx')
df = pd.DataFrame()
df['RNN'] = sorted(df1[0])
df['LSTM'] = sorted(df2[0])
df['GRU'] = sorted(df3[0])
df['RNN_LSTM'] = sorted(df4[0])
df['RNN_GRU'] = sorted(df5[0])
df['LSTM_RNN'] = sorted(df6[0])
df['GRU_RNN'] = sorted(df7[0])
df['LSTM_GRU'] = sorted(df8[0])
df['GRU_LSTM'] = sorted(df9[0])

# Rename the columns
df.columns = ['RNN', 'LSTM', 'GRU', 'RNN-LSTM', 'RNN-GRU',
              'LSTM-RNN', 'GRU-RNN', 'LSTM-GRU', 'GRU-LSTM']
n = int(len(df) * 0.025)
df = df.iloc[n:-n]
data = df.copy()

# Boxplot customizations
fig, ax = plt.subplots(figsize=(20, 10))
plt.boxplot(
    data.values,
    labels=data.columns,
    boxprops=dict(color='blue'),
    whiskerprops=dict(color='red'),
    capprops=dict(color='purple'),
    flierprops=dict(markerfacecolor='black', marker='o', markersize=8),
    medianprops=dict(color='green')
)

# Enlarge the x-axis and y-axis labels
plt.xlabel('Models', fontsize=22)
plt.ylabel('Root Mean Square Error', fontsize=22)
plt.yticks(fontsize=20)

# Enlarge the labels for the boxplot
for tick in ax.get_xticklabels():
    tick.set_fontsize(20)
#    tick.set_fontweight('bold')

# Add the mean annotations
for i, column in enumerate(data.columns):
    mean = np.mean(data[column])
    plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom', color='black', fontsize=18)

plt.tight_layout()

# Step 3: Save the figure in Google Drive
plt.savefig(folder_path + 'Comparison_RMSE_Dataset1.pdf', dpi=300)

# If you want to download the figure from Google Drive:
# files.download(folder_path + 'Comparison_MAE_Dataset1.pdf')

# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#TIME

from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the folder path in Google Drive
# For example, saving to a folder named 'Figures' in 'My Drive'
folder_path = '/content/drive/My Drive/Figures/'

# Example plot (using your boxplot code or any other plot)

# Assuming df1, df2, ... df9 are already defined

df1 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN_TIME.xlsx')
df2 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM_TIME.xlsx')
df3 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU_TIME.xlsx')
df4 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN-LSTM_TIME.xlsx')
df5 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/RNN-GRU_TIME.xlsx')
df6 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM-RNN_TIME.xlsx')
df7 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU-RNN_TIME.xlsx')
df8 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/LSTM-GRU_TIME.xlsx')
df9 = pd.read_excel('/content/drive/My Drive/Figures/sunspot/GRU-LSTM_TIME.xlsx')
df = pd.DataFrame()

df['RNN'] = df1[0]
df['LSTM'] = df2[0]
df['GRU'] = df3[0]
df['RNN_LSTM'] = df4[0]
df['RNN_GRU'] = df5[0]
df['LSTM_RNN'] = df6[0]
df['GRU_RNN'] = df7[0]
df['LSTM_GRU'] = df8[0]
df['GRU_LSTM'] = df9[0]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
average_times = df.mean()
# Create a bar chart
plt.figure(figsize=(20, 12))
average_times.plot(kind='bar', color='skyblue')
#plt.title('Comparison of Computational Time Across Different Models')
plt.xlabel('Models' , fontsize=22)
plt.ylabel('Average Time (s)' , fontsize=22)
plt.xticks(fontsize = 18, rotation=0)
plt.yticks(fontsize = 18)
#for tick in ax.get_xticklabels():
#    tick.set_fontsize(18)
plt.tight_layout()
# Display the average times on top of the bars
for i, v in enumerate(average_times):
  plt.text(i, v, f"{v:.2f}", ha='center', va='bottom', fontsize=18)

plt.savefig(folder_path + 'Comparison_Time_Dataset1-bar chart-rev.pdf', dpi=300)
#files.download("Comparison_Time_Dataset1.pdf")
plt.show()

# %%
###################
#DATASET 2
##################
from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the folder path in Google Drive
# For example, saving to a folder named 'Figures' in 'My Drive'
folder_path = '/content/drive/My Drive/Figures/'

# Example plot (using your boxplot code or any other plot)

# Assuming df1, df2, ... df9 are already defined

df1 = pd.read_excel('/content/drive/My Drive/Figures/RNN_FORECASTMae.xlsx')
df2 = pd.read_excel('/content/drive/My Drive/Figures/LSTM_FORECASTMae.xlsx')
df3 = pd.read_excel('/content/drive/My Drive/Figures/GRU_FORECASTMae.xlsx')
df4 = pd.read_excel('/content/drive/My Drive/Figures/RNN_LSTM_FORECASTMae.xlsx')
df5 = pd.read_excel('/content/drive/My Drive/Figures/RNN_GRU_FORECASTMae.xlsx')
df6 = pd.read_excel('/content/drive/My Drive/Figures/LSTM_RNN_FORECASTMae.xlsx')
df7 = pd.read_excel('/content/drive/My Drive/Figures/GRU_RNN_FORECASTMae.xlsx')
df8 = pd.read_excel('/content/drive/My Drive/Figures/LSTM_GRU_FORECASTMae.xlsx')
df9 = pd.read_excel('/content/drive/My Drive/Figures/GRU_LSTM_FORECASTMae.xlsx')
df = pd.DataFrame()
df['RNN'] = sorted(df1[0])
df['LSTM'] = sorted(df2[0])
df['GRU'] = sorted(df3[0])
df['RNN_LSTM'] = sorted(df4[0])
df['RNN_GRU'] = sorted(df5[0])
df['LSTM_RNN'] = sorted(df6[0])
df['GRU_RNN'] = sorted(df7[0])
df['LSTM_GRU'] = sorted(df8[0])
df['GRU_LSTM'] = sorted(df9[0])

# Rename the columns
df.columns = ['RNN', 'LSTM', 'GRU', 'RNN-LSTM', 'RNN-GRU',
              'LSTM-RNN', 'GRU-RNN', 'LSTM-GRU', 'GRU-LSTM']
n = int(len(df) * 0.025)
df = df.iloc[n:-n]
data = df.copy()

# Boxplot customizations
fig, ax = plt.subplots(figsize=(20, 10))
plt.boxplot(
    data.values,
    labels=data.columns,
    boxprops=dict(color='blue'),
    whiskerprops=dict(color='red'),
    capprops=dict(color='purple'),
    flierprops=dict(markerfacecolor='black', marker='o', markersize=8),
    medianprops=dict(color='green')
)

# Enlarge the x-axis and y-axis labels
plt.xlabel('Models', fontsize=22)
plt.ylabel('Mean Average Error', fontsize=22)
plt.yticks(fontsize=20)

# Enlarge the labels for the boxplot
for tick in ax.get_xticklabels():
    tick.set_fontsize(20)
#    tick.set_fontweight('bold')

# Add the mean annotations
for i, column in enumerate(data.columns):
    mean = np.mean(data[column])
    plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom', color='black', fontsize=18)

plt.tight_layout()

# Step 3: Save the figure in Google Drive
plt.savefig(folder_path + 'Comparison_MAE_Dataset2.pdf', dpi=300)

# If you want to download the figure from Google Drive:
# files.download(folder_path + 'Comparison_MAE_Dataset1.pdf')

# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
###################
#DATASET 2
##################
from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the folder path in Google Drive
# For example, saving to a folder named 'Figures' in 'My Drive'
folder_path = '/content/drive/My Drive/Figures/'

# Example plot (using your boxplot code or any other plot)

# Assuming df1, df2, ... df9 are already defined

df1 = pd.read_excel('/content/drive/My Drive/Figures/RNN_FORECASTRMse.xlsx')
df2 = pd.read_excel('/content/drive/My Drive/Figures/LSTM_FORECASTRMse.xlsx')
df3 = pd.read_excel('/content/drive/My Drive/Figures/GRU_FORECASTRMse.xlsx')
df4 = pd.read_excel('/content/drive/My Drive/Figures/RNN-LSTM_FORECASTRMse.xlsx')
df5 = pd.read_excel('/content/drive/My Drive/Figures/RNN-GRU_FORECASTRMse.xlsx')
df6 = pd.read_excel('/content/drive/My Drive/Figures/LSTM-RNN_FORECASTRMse.xlsx')
df7 = pd.read_excel('/content/drive/My Drive/Figures/GRU-RNN_FORECASTRMse.xlsx')
df8 = pd.read_excel('/content/drive/My Drive/Figures/LSTM-GRU_FORECASTRMse.xlsx')
df9 = pd.read_excel('/content/drive/My Drive/Figures/GRU-LSTM_FORECASTRMse.xlsx')
df = pd.DataFrame()
df['RNN'] = sorted(df1['RMSE'])
df['LSTM'] = sorted(df2['RMSE'])
df['GRU'] = sorted(df3['RMSE'])
df['RNN_LSTM'] = sorted(df4['RMSE'])
df['RNN_GRU'] = sorted(df5['RMSE'])
df['LSTM_RNN'] = sorted(df6['RMSE'])
df['GRU_RNN'] = sorted(df7['RMSE'])
df['LSTM_GRU'] = sorted(df8['RMSE'])
df['GRU_LSTM'] = sorted(df9['RMSE'])

# Rename the columns
df.columns = ['RNN', 'LSTM', 'GRU', 'RNN-LSTM', 'RNN-GRU',
              'LSTM-RNN', 'GRU-RNN', 'LSTM-GRU', 'GRU-LSTM']
n = int(len(df) * 0.025)
df = df.iloc[n:-n]
data = df.copy()

# Boxplot customizations
fig, ax = plt.subplots(figsize=(20, 10))
plt.boxplot(
    data.values,
    labels=data.columns,
    boxprops=dict(color='blue'),
    whiskerprops=dict(color='red'),
    capprops=dict(color='purple'),
    flierprops=dict(markerfacecolor='black', marker='o', markersize=8),
    medianprops=dict(color='green')
)

# Enlarge the x-axis and y-axis labels
plt.xlabel('Models', fontsize=22)
plt.ylabel('Root Mean Square Error', fontsize=22)
plt.yticks(fontsize=20)

# Enlarge the labels for the boxplot
for tick in ax.get_xticklabels():
    tick.set_fontsize(18)
#    tick.set_fontweight('bold')

# Add the mean annotations
for i, column in enumerate(data.columns):
    mean = np.mean(data[column])
    plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom', color='black', fontsize=18)

plt.tight_layout()

# Step 3: Save the figure in Google Drive
plt.savefig(folder_path + 'Comparison_RMSE_Dataset2.pdf', dpi=300)

# If you want to download the figure from Google Drive:
# files.download(folder_path + 'Comparison_MAE_Dataset1.pdf')

# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the folder path in Google Drive
# For example, saving to a folder named 'Figures' in 'My Drive'
folder_path = '/content/drive/My Drive/Figures/'

# Example plot (using your boxplot code or any other plot)

# Assuming df1, df2, ... df9 are already defined

df1 = pd.read_excel('/content/drive/My Drive/Figures/RNN_FORECASTMpe.xlsx')
df2 = pd.read_excel('/content/drive/My Drive/Figures/LSTM_FORECASTMpe.xlsx')
df3 = pd.read_excel('/content/drive/My Drive/Figures/GRU_FORECASTMpe.xlsx')
df4 = pd.read_excel('/content/drive/My Drive/Figures/RNN-LSTM_FORECASTMpe.xlsx')
df5 = pd.read_excel('/content/drive/My Drive/Figures/RNN-GRU_FORECASTMpe.xlsx')
df6 = pd.read_excel('/content/drive/My Drive/Figures/LSTM-RNN_FORECASTMpe.xlsx')
df7 = pd.read_excel('/content/drive/My Drive/Figures/GRU-RNN_FORECASTMpe.xlsx')
df8 = pd.read_excel('/content/drive/My Drive/Figures/LSTM-GRU_FORECASTMpe.xlsx')
df9 = pd.read_excel('/content/drive/My Drive/Figures/GRU-LSTM_FORECASTMpe.xlsx')
df = pd.DataFrame()
df['RNN'] = sorted(df1['MAPE'])
df['LSTM'] = sorted(df2['MAPE'])
df['GRU'] = sorted(df3['MAPE'])
df['RNN_LSTM'] = sorted(df4['MAPE'])
df['RNN_GRU'] = sorted(df5['MAPE'])
df['LSTM_RNN'] = sorted(df6['MAPE'])
df['GRU_RNN'] = sorted(df7['MAPE'])
df['LSTM_GRU'] = sorted(df8['MAPE'])
df['GRU_LSTM'] = sorted(df9['MAPE'])

# Rename the columns
df.columns = ['RNN', 'LSTM', 'GRU', 'RNN-LSTM', 'RNN-GRU',
              'LSTM-RNN', 'GRU-RNN', 'LSTM-GRU', 'GRU-LSTM']
n = int(len(df) * 0.025)
df = df.iloc[n:-n]
data = df.copy()

# Boxplot customizations
fig, ax = plt.subplots(figsize=(20, 10))
plt.boxplot(
    data.values,
    labels=data.columns,
    boxprops=dict(color='blue'),
    whiskerprops=dict(color='red'),
    capprops=dict(color='purple'),
    flierprops=dict(markerfacecolor='black', marker='o', markersize=8),
    medianprops=dict(color='green')
)

# Enlarge the x-axis and y-axis labels
plt.xlabel('Models', fontsize=22)
plt.ylabel('Mean Absolute Percentage Error', fontsize=22)
plt.yticks(fontsize=20)

# Enlarge the labels for the boxplot
for tick in ax.get_xticklabels():
    tick.set_fontsize(18)
#    tick.set_fontweight('bold')

# Add the mean annotations
for i, column in enumerate(data.columns):
    mean = np.mean(data[column])
    plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom', color='black', fontsize=18)

plt.tight_layout()

# Step 3: Save the figure in Google Drive
plt.savefig(folder_path + 'Comparison_MAPE_Dataset2.pdf', dpi=300)

# If you want to download the figure from Google Drive:
# files.download(folder_path + 'Comparison_MAE_Dataset1.pdf')

# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Hasil ini mungkin akan error, karena gdown nya dari dataset 2 tentang waktu belum diambil
# bisa dimatikan dan ulangi lagi / read data time dulu
df1 = pd.read_excel('/content/RNN_TIME.xlsx')
df2 = pd.read_excel('/content/LSTM_TIME.xlsx')
df3 = pd.read_excel('/content/GRU_TIME.xlsx')
df4 = pd.read_excel('/content/RNN-LSTM_TIME.xlsx')
df5 = pd.read_excel('/content/RNN-GRU_TIME.xlsx')
df6 = pd.read_excel('/content/LSTM-RNN_TIME.xlsx')
df7 = pd.read_excel('/content/GRU-RNN_TIME.xlsx')
df8 = pd.read_excel('/content/LSTM-GRU_TIME.xlsx')
df9 = pd.read_excel('/content/GRU-LSTM_TIME.xlsx')
df = pd.DataFrame()
df['RNN'] = df1[0]
df['LSTM'] = df2[0]
df['GRU'] = df3[0]
df['RNN_LSTM'] = df4[0]
df['RNN_GRU'] = df5[0]
df['LSTM_RNN'] = df6[0]
df['GRU_RNN'] = df7[0]
df['LSTM_GRU'] = df8[0]
df['GRU_LSTM'] = df9[0]

# %%
average_times = df.mean()
# Create a bar chart
plt.figure(figsize=(20, 12))
average_times.plot(kind='bar', color='skyblue')
#plt.title('Comparison of Computational Time Across Different Models')
plt.xlabel('Models' , fontsize=22)
plt.ylabel('Average Time (s)' , fontsize=22)
plt.xticks(fontsize = 18, rotation=0)
plt.yticks(fontsize=18)
#for tick in ax.get_xticklabels():
#    tick.set_fontsize(18)
plt.tight_layout()
# Display the average times on top of the bars
for i, v in enumerate(average_times):
  plt.text(i, v, f"{v:.2f}", ha='center', va='bottom', fontsize=18)

plt.savefig(folder_path + 'Comparison_Time_Dataset2.pdf', dpi=300)
#files.download("Comparison_Time_Dataset1.pdf")
plt.show()

# %%
#################################
# Dataset 3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# %%
# !gdown 1_bfo8AtzgY1aTlBMkCQTeXZJgvpya_jy
# !gdown 1Yfwmvc33LCqBRolk0cht_U0z8Dm2e94r
# !gdown 1SlDSpcjwyok5cvllKSBIkhmgcEMsniXw
# !gdown 1keYxJghjd3PS_RKCG8pAMZ_rKED9bR1I
# !gdown 1C-8SpOb3URkXvOfv2MT_8F1BXhG_z6yC
# !gdown 1lWRg123gdALQdFHd8Y7YKBBuFWV9AJz3
# !gdown 1ABT_xEk_8wSQ7GAUdb4_zl_P5aqao3AC
# !gdown 1KhQuc5NO8DM2lSsQHFMc_Asj8AC_gCix
# !gdown 1j0grY7SJMdeOUE8xJ_C8pAfzSLxWn32p
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_bfo8AtzgY1aTlBMkCQTeXZJgvpya_jy
# To: /content/RNN_FORECASTMae.xlsx
# 100% 6.50k/6.50k [00:00<00:00, 19.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Yfwmvc33LCqBRolk0cht_U0z8Dm2e94r
# To: /content/RNN_FORECASTMpe.xlsx
# 100% 6.53k/6.53k [00:00<00:00, 21.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1SlDSpcjwyok5cvllKSBIkhmgcEMsniXw
# To: /content/RNN_FORECASTRMse.xlsx
# 100% 6.50k/6.50k [00:00<00:00, 16.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1keYxJghjd3PS_RKCG8pAMZ_rKED9bR1I
# To: /content/LSTM_FORECASTMae.xlsx
# 100% 6.49k/6.49k [00:00<00:00, 23.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1C-8SpOb3URkXvOfv2MT_8F1BXhG_z6yC
# To: /content/LSTM_FORECASTMpe.xlsx
# 100% 6.52k/6.52k [00:00<00:00, 23.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1lWRg123gdALQdFHd8Y7YKBBuFWV9AJz3
# To: /content/LSTM_FORECASTRMse.xlsx
# ...

# %%
# !gdown 1u3QM7s9U4X1zwhXoIyMUlUHL9MP2m7lA
# !gdown 1n-qg3c_F7CdKRu4J-pvosOPifeOFpyXT
# !gdown 1eHWoOj9Hjnqq953qF7GnuOqBHAZO6btU
# !gdown 14CvG2kBlZc0iGIN2yiE3IHbYTJp1lcbX
# !gdown 11wAUYeSh6ABH5CdguGh9Db8m206b1BHy
# !gdown 1Hs82CjFvveFxVVhq7khEN80zw5JgX2YW
# !gdown 1Yu32XV9IWjqMmIlD58hccDKvXhfYBRz-
# !gdown 18fIbFzz1IDCieyI3AzCOw51TLMD4jNE_
# !gdown 1rvpQ9cuZ2oz_vJfR71wbAAiT2WAvkOaN
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1u3QM7s9U4X1zwhXoIyMUlUHL9MP2m7lA
# To: /content/RNN-GRU_FORECASTMae.xlsx
# 100% 6.49k/6.49k [00:00<00:00, 13.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1n-qg3c_F7CdKRu4J-pvosOPifeOFpyXT
# To: /content/RNN-GRU_FORECASTMpe.xlsx
# 100% 6.50k/6.50k [00:00<00:00, 14.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1eHWoOj9Hjnqq953qF7GnuOqBHAZO6btU
# To: /content/RNN-GRU_FORECASTRMse.xlsx
# 100% 6.48k/6.48k [00:00<00:00, 22.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=14CvG2kBlZc0iGIN2yiE3IHbYTJp1lcbX
# To: /content/RNN-LSTM_FORECASTMae.xlsx
# 100% 6.50k/6.50k [00:00<00:00, 22.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11wAUYeSh6ABH5CdguGh9Db8m206b1BHy
# To: /content/RNN-LSTM_FORECASTMpe.xlsx
# 100% 6.51k/6.51k [00:00<00:00, 17.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Hs82CjFvveFxVVhq7khEN80zw5JgX2YW
# To: /content/RNN-LSTM_FORECASTRMse.xlsx
# ...

# %%
# !gdown 1pFi3Ak4tDjpP_bqFlq-TpIsY3BdN9iKB
# !gdown 1ZMIRCHq8ixaqIbMNBKezMbJF_1HxufSm
# !gdown 1ZWkYruyNyXxzfen4nX35EGqMhU8RqfCm
# !gdown 1-R3HgWubX2WPGExnivgaDkngXCC4gwwI
# !gdown 1jZRd9ZPvhqdMoqkrOSWAZF-VTnOpGVBT
# !gdown 1u9v7m9DhtGDBxMRC5nIpeP2WdxDQzYCv
# !gdown 1heElB_3Y-EfZ3NvRQyJfEaVtjKYbT7IJ
# !gdown 1tzPKVzJQWdvOb3VlcaFb2Cl-OlbUzaoj
# !gdown 1yfnad4_9xfyV07ChCwNY2QVO6CMwwY8C
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1pFi3Ak4tDjpP_bqFlq-TpIsY3BdN9iKB
# To: /content/LSTM-GRU_FORECASTMae.xlsx
# 100% 6.49k/6.49k [00:00<00:00, 22.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZMIRCHq8ixaqIbMNBKezMbJF_1HxufSm
# To: /content/LSTM-GRU_FORECASTMpe.xlsx
# 100% 6.51k/6.51k [00:00<00:00, 19.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZWkYruyNyXxzfen4nX35EGqMhU8RqfCm
# To: /content/LSTM-GRU_FORECASTRMse.xlsx
# 100% 6.49k/6.49k [00:00<00:00, 16.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-R3HgWubX2WPGExnivgaDkngXCC4gwwI
# To: /content/GRU-RNN_FORECASTMae.xlsx
# 100% 6.49k/6.49k [00:00<00:00, 22.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1jZRd9ZPvhqdMoqkrOSWAZF-VTnOpGVBT
# To: /content/GRU-RNN_FORECASTMpe.xlsx
# 100% 6.51k/6.51k [00:00<00:00, 22.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1u9v7m9DhtGDBxMRC5nIpeP2WdxDQzYCv
# To: /content/GRU-RNN_FORECASTRMse.xlsx
# ...

# %%
# !gdown 1LgzOypyseSxSi6npx4uqU06qQlYiLaBW
# !gdown 1UPlXMWGCECg95bikCPMQL4S74ulyDiJf
# !gdown 1WC68Tph806l4Lh9M8OoC-k0mbYTCdmvg
# !gdown 1FtcLm4T-Kf7NFUtaJFRt4G0XB1iHMLt3
# !gdown 1_wKEcb1Y-4Ixm7kCeTwvSDPKmXDGBLMv
# !gdown 19xKB1I7u4y-OeE89eKRBX6w7aVpT_ZTA
# !gdown 1Wq8TYAz_HUf7ixW8k3wvALsxjnGwbMy2
# !gdown 1QyL2vIpZEbo84zcZxdB0W4B3_J-CzLvG
# !gdown 1hraImwtrxdcxxwPsLAiwtqXNxCc-z4Kz
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LgzOypyseSxSi6npx4uqU06qQlYiLaBW
# To: /content/GRU-LSTM_TIME.xlsx
# 100% 6.51k/6.51k [00:00<00:00, 15.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1UPlXMWGCECg95bikCPMQL4S74ulyDiJf
# To: /content/GRU-RNN_TIME.xlsx
# 100% 6.48k/6.48k [00:00<00:00, 23.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1WC68Tph806l4Lh9M8OoC-k0mbYTCdmvg
# To: /content/LSTM-GRU_TIME.xlsx
# 100% 6.46k/6.46k [00:00<00:00, 16.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FtcLm4T-Kf7NFUtaJFRt4G0XB1iHMLt3
# To: /content/LSTM-RNN_TIME.xlsx
# 100% 6.49k/6.49k [00:00<00:00, 23.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_wKEcb1Y-4Ixm7kCeTwvSDPKmXDGBLMv
# To: /content/RNN-GRU_TIME.xlsx
# 100% 6.51k/6.51k [00:00<00:00, 21.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19xKB1I7u4y-OeE89eKRBX6w7aVpT_ZTA
# To: /content/RNN-LSTM_TIME.xlsx
# 100% 6.50k/6.50k [00:00<00:00, 21.2MB/s]
# ...

# %%
###################
#DATASET 2
##################
from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the folder path in Google Drive
# For example, saving to a folder named 'Figures' in 'My Drive'
folder_path = '/content/drive/My Drive/Figures/'

# Example plot (using your boxplot code or any other plot)

# Assuming df1, df2, ... df9 are already defined

df1 = pd.read_excel('/content/RNN_FORECASTMae.xlsx')
df2 = pd.read_excel('/content/LSTM_FORECASTMae.xlsx')
df3 = pd.read_excel('/content/GRU_FORECASTMae.xlsx')
df4 = pd.read_excel('/content/RNN-LSTM_FORECASTMae.xlsx')
df5 = pd.read_excel('/content/RNN-GRU_FORECASTMae.xlsx')
df6 = pd.read_excel('/content/LSTM-RNN_FORECASTMae.xlsx')
df7 = pd.read_excel('/content/GRU-RNN_FORECASTMae.xlsx')
df8 = pd.read_excel('/content/LSTM-GRU_FORECASTMae.xlsx')
df9 = pd.read_excel('/content/GRU-LSTM_FORECASTMae.xlsx')
df = pd.DataFrame()
df['RNN'] = sorted(df1[0])
df['LSTM'] = sorted(df2[0])
df['GRU'] = sorted(df3[0])
df['RNN_LSTM'] = sorted(df4[0])
df['RNN_GRU'] = sorted(df5[0])
df['LSTM_RNN'] = sorted(df6[0])
df['GRU_RNN'] = sorted(df7[0])
df['LSTM_GRU'] = sorted(df8[0])
df['GRU_LSTM'] = sorted(df9[0])

# Rename the columns
df.columns = ['RNN', 'LSTM', 'GRU', 'RNN-LSTM', 'RNN-GRU',
              'LSTM-RNN', 'GRU-RNN', 'LSTM-GRU', 'GRU-LSTM']
n = int(len(df) * 0.025)
df = df.iloc[n:-n]
data = df.copy()

# Boxplot customizations
fig, ax = plt.subplots(figsize=(20, 10))
plt.boxplot(
    data.values,
    labels=data.columns,
    boxprops=dict(color='blue'),
    whiskerprops=dict(color='red'),
    capprops=dict(color='purple'),
    flierprops=dict(markerfacecolor='black', marker='o', markersize=8),
    medianprops=dict(color='green')
)

# Enlarge the x-axis and y-axis labels
plt.xlabel('Models', fontsize=22)
plt.ylabel('Mean Average Error', fontsize=22)
plt.yticks(fontsize=20)

# Enlarge the labels for the boxplot
for tick in ax.get_xticklabels():
    tick.set_fontsize(20)
#    tick.set_fontweight('bold')

# Add the mean annotations
for i, column in enumerate(data.columns):
    mean = np.mean(data[column])
    plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom', color='black', fontsize=18)

plt.tight_layout()

# Step 3: Save the figure in Google Drive
plt.savefig(folder_path + 'Comparison_MAE_Dataset3.pdf', dpi=300)

# If you want to download the figure from Google Drive:
# files.download(folder_path + 'Comparison_MAE_Dataset1.pdf')

# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
###################
#DATASET 3 RMSE
##################
from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the folder path in Google Drive
# For example, saving to a folder named 'Figures' in 'My Drive'
folder_path = '/content/drive/My Drive/Figures/'

# Example plot (using your boxplot code or any other plot)

# Assuming df1, df2, ... df9 are already defined

df1 = pd.read_excel('/content/RNN_FORECASTRMse.xlsx')
df2 = pd.read_excel('/content/LSTM_FORECASTRMse.xlsx')
df3 = pd.read_excel('/content/GRU_FORECASTRMse.xlsx')
df4 = pd.read_excel('/content/RNN-LSTM_FORECASTRMse.xlsx')
df5 = pd.read_excel('/content/RNN-GRU_FORECASTRMse.xlsx')
df6 = pd.read_excel('/content/LSTM-RNN_FORECASTRMse.xlsx')
df7 = pd.read_excel('/content/GRU-RNN_FORECASTRMse.xlsx')
df8 = pd.read_excel('/content/LSTM-GRU_FORECASTRMse.xlsx')
df9 = pd.read_excel('/content/GRU-LSTM_FORECASTRMse.xlsx')
df = pd.DataFrame()
df['RNN'] = sorted(df1[0])
df['LSTM'] = sorted(df2[0])
df['GRU'] = sorted(df3[0])
df['RNN_LSTM'] = sorted(df4[0])
df['RNN_GRU'] = sorted(df5[0])
df['LSTM_RNN'] = sorted(df6[0])
df['GRU_RNN'] = sorted(df7[0])
df['LSTM_GRU'] = sorted(df8[0])
df['GRU_LSTM'] = sorted(df9[0])

# Rename the columns
df.columns = ['RNN', 'LSTM', 'GRU', 'RNN-LSTM', 'RNN-GRU',
              'LSTM-RNN', 'GRU-RNN', 'LSTM-GRU', 'GRU-LSTM']
n = int(len(df) * 0.025)
df = df.iloc[n:-n]
data = df.copy()

# Boxplot customizations
fig, ax = plt.subplots(figsize=(20, 10))
plt.boxplot(
    data.values,
    labels=data.columns,
    boxprops=dict(color='blue'),
    whiskerprops=dict(color='red'),
    capprops=dict(color='purple'),
    flierprops=dict(markerfacecolor='black', marker='o', markersize=8),
    medianprops=dict(color='green')
)

# Enlarge the x-axis and y-axis labels
plt.xlabel('Models', fontsize=22)
plt.ylabel('Root Mean Square Error', fontsize=22)
plt.yticks(fontsize=20)

# Enlarge the labels for the boxplot
for tick in ax.get_xticklabels():
    tick.set_fontsize(18)
#    tick.set_fontweight('bold')

# Add the mean annotations
for i, column in enumerate(data.columns):
    mean = np.mean(data[column])
    plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom', color='black', fontsize=18)

plt.tight_layout()

# Step 3: Save the figure in Google Drive
plt.savefig(folder_path + 'Comparison_RMSE_Dataset3.pdf', dpi=300)


# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the folder path in Google Drive
# For example, saving to a folder named 'Figures' in 'My Drive'
folder_path = '/content/drive/My Drive/Figures/'

# Example plot (using your boxplot code or any other plot)

# Assuming df1, df2, ... df9 are already defined

df1 = pd.read_excel('/content/RNN_FORECASTMpe.xlsx')
df2 = pd.read_excel('/content/LSTM_FORECASTMpe.xlsx')
df3 = pd.read_excel('/content/GRU_FORECASTMpe.xlsx')
df4 = pd.read_excel('/content/RNN-LSTM_FORECASTMpe.xlsx')
df5 = pd.read_excel('/content/RNN-GRU_FORECASTMpe.xlsx')
df6 = pd.read_excel('/content/LSTM-RNN_FORECASTMpe.xlsx')
df7 = pd.read_excel('/content/GRU-RNN_FORECASTMpe.xlsx')
df8 = pd.read_excel('/content/LSTM-GRU_FORECASTMpe.xlsx')
df9 = pd.read_excel('/content/GRU-LSTM_FORECASTMpe.xlsx')
df = pd.DataFrame()
df['RNN'] = df1[0]
df['LSTM'] = df2[0]
df['GRU'] = df3[0]
df['RNN_LSTM'] = df4[0]
df['RNN_GRU'] = df5[0]
df['LSTM_RNN'] = df6[0]
df['GRU_RNN'] = df7[0]
df['LSTM_GRU'] = df8[0]
df['GRU_LSTM'] = df9[0]

n = int(len(df) * 0.025)
df = df[:].iloc[n:-n]
data = df[:]

# Rename the columns
df.columns = ['RNN', 'LSTM', 'GRU', 'RNN-LSTM', 'RNN-GRU',
              'LSTM-RNN', 'GRU-RNN', 'LSTM-GRU', 'GRU-LSTM']
n = int(len(df) * 0.025)
df = df.iloc[n:-n]
data = df.copy()

# Boxplot customizations
fig, ax = plt.subplots(figsize=(20, 10))
plt.boxplot(
    data.values,
    labels=data.columns,
    boxprops=dict(color='blue'),
    whiskerprops=dict(color='red'),
    capprops=dict(color='purple'),
    flierprops=dict(markerfacecolor='black', marker='o', markersize=8),
    medianprops=dict(color='green')
)

# Enlarge the x-axis and y-axis labels
plt.xlabel('Models', fontsize=22)
plt.ylabel('Mean Absolute Percentage Error', fontsize=22)
plt.yticks(fontsize=20)

# Enlarge the labels for the boxplot
for tick in ax.get_xticklabels():
    tick.set_fontsize(18)
#    tick.set_fontweight('bold')

# Add the mean annotations
for i, column in enumerate(data.columns):
    mean = np.mean(data[column])
    plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom', color='black', fontsize=18)

plt.tight_layout()

# Step 3: Save the figure in Google Drive
plt.savefig(folder_path + 'Comparison_MAPE_Dataset3.pdf', dpi=300)

# If you want to download the figure from Google Drive:
# files.download(folder_path + 'Comparison_MAE_Dataset1.pdf')

# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_excel('/content/RNN_TIME.xlsx')
df2 = pd.read_excel('/content/LSTM_TIME.xlsx')
df3 = pd.read_excel('/content/GRU_TIME.xlsx')
df4 = pd.read_excel('/content/RNN-LSTM_TIME.xlsx')
df5 = pd.read_excel('/content/RNN-GRU_TIME.xlsx')
df6 = pd.read_excel('/content/LSTM-RNN_TIME.xlsx')
df7 = pd.read_excel('/content/GRU-RNN_TIME.xlsx')
df8 = pd.read_excel('/content/LSTM-GRU_TIME.xlsx')
df9 = pd.read_excel('/content/GRU-LSTM_TIME.xlsx')
df = pd.DataFrame()
df['RNN'] = df1[0]
df['LSTM'] = df2[0]
df['GRU'] = df3[0]
df['RNN_LSTM'] = df4[0]
df['RNN_GRU'] = df5[0]
df['LSTM_RNN'] = df6[0]
df['GRU_RNN'] = df7[0]
df['LSTM_GRU'] = df8[0]
df['GRU_LSTM'] = df9[0]

# Calculate the average time for each model
average_times = df.mean()
# Create a bar chart
plt.figure(figsize=(20, 12))
average_times.plot(kind='bar', color='skyblue')
#plt.title('Comparison of Computational Time Across Different Models')
plt.xlabel('Models' , fontsize=22)
plt.ylabel('Average Time (s)' , fontsize=22)
plt.xticks(fontsize = 18, rotation=0)
plt.yticks(fontsize = 18)
plt.tight_layout()
# Display the average times on top of the bars
for i, v in enumerate(average_times):
  plt.text(i, v, f"{v:.2f}", ha='center', va='bottom',  fontsize=18)
plt.savefig(folder_path + 'Comparison_Time_Dataset3.pdf', dpi=300)

plt.show()

# %%
# Ulangi Lagi dataset 2 yang waktu, karena kok jadi berubah
# !gdown 1_Xk_aBt72cg0IhtrDHByatBuGuLi-svr
# !gdown 1ZrtG6EfZxXeV19WMzla_qniBb4E0vHGp
# !gdown 1YCs0hRgt-wpSVI7EbtLit5HvjM7brmtB
# !gdown 194--ZfpP3lr5eg8jfjbDLSWDSvWVVx18
# !gdown 1mrYem8IETC1Bvv4XLfkuFc_Yxs0L-1M5
# !gdown 11ElHC2LM013wujQwqW12SD6gDrv60mOl
# !gdown 1f62wFr9ML2AAO39aeU2dbKsmh3idLyOi
# !gdown 1EImqlbcinVzjSxp5wM27YfCo9Nf_YBn0
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_Xk_aBt72cg0IhtrDHByatBuGuLi-svr
# To: /content/RNN_TIME.xlsx
# 100% 10.3k/10.3k [00:00<00:00, 29.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZrtG6EfZxXeV19WMzla_qniBb4E0vHGp
# To: /content/RNN_FORECASTRMse.xlsx
# 100% 6.52k/6.52k [00:00<00:00, 21.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1YCs0hRgt-wpSVI7EbtLit5HvjM7brmtB
# To: /content/RNN_FORECASTMpe.xlsx
# 100% 6.50k/6.50k [00:00<00:00, 19.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=194--ZfpP3lr5eg8jfjbDLSWDSvWVVx18
# To: /content/RNN_FORECASTMae.xlsx
# 100% 6.48k/6.48k [00:00<00:00, 22.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1mrYem8IETC1Bvv4XLfkuFc_Yxs0L-1M5
# To: /content/LSTM_TIME.xlsx
# 100% 10.3k/10.3k [00:00<00:00, 27.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11ElHC2LM013wujQwqW12SD6gDrv60mOl
# To: /content/LSTM_FORECASTRMse.xlsx
# ...

# %%
# !gdown 1NyWC6xVK2tlvtjcx0xv8I4O_bI0KebdS
# !gdown 1UFgEoC6-313M_dpjq7mW9LICaUvbkoNa
# !gdown 1vuERyAz3ckNgg_vAAcjznPa7jpNJN9Rt
# !gdown 1ZumVvaJpYdkWhSKZNlqbrHzi--A3iwtx
# !gdown 1z0qcyj5D7XoZ4bTMDZ3yaOuHaFaqmXSZ
# !gdown 16dF5YhHT4R_g5HbdAsO_cEXejJQ87Pg2
# !gdown 1DLTaT7OQxd_R71nSjjj7r7NSJfkG0X8X
# !gdown 1A1ARznJ4X2xQM5AL05yfhZo6KIQ21rxZ
# !gdown 1fvzFbPqCzqdoLujlHxqIqNlnuCRPddTV
# !gdown 1avI3Q59EZV92abBlLrSjNYG05ndLcOJ9
# !gdown 16ZR-PaPNwqSyzFj-0SS8AqB7xIJ4OrYe
# !gdown 1SgjgWPVq-QTgva1OFAZNKrVzQr0aJwRr
# !gdown 1b1zT-srRQd1PEmXi2MyhojUFTGhPTHBM
# !gdown 1zsmjBebdjFhh-tm8V4zPF9rQDKs76Vyv
# !gdown 1raNErRqrAcr5qFCXH2T1G4bqhbu6l-m5
# !gdown 1MHL7n1sIjWsouMWbYfgvDLud-Ba6wWM1
# !gdown 1FblK2jeAC9kkZsRp9I6o-64Uqtpql-XI
# !gdown 1n718TN1i5kwMEIm0Q6NTcz94D34YXgpA
# !gdown 1oy-KECRHSE07R7-78D1tBdiJNbEoxI8E
# !gdown 19--phk8Mf1z4QX464ZV_wVL4hfyQmSW1
# !gdown 1-JzfQA2dQJe-mXrEK7fdNY1HluF_wSHQ
# !gdown 16NiUOKZgspf09ztmREbffpmBKV9zBRhX
# !gdown 1mb0yBP7A5seQN2naL8Sgqy54pZ5lYZAZ
# !gdown 1CUxws0PZc8T_LWIKyifATBfOzFGMXBi9
# !gdown 1ajESJp2rNjlmdWa31-2iIvE8lyvkGKgS
# !gdown 14M9gs549r7PLS2CAjEbLoQOiaRfey6X8
# !gdown 1j7YuYNeVF4Jt3F3tqG1oH4qgpGwF99jC
# !gdown 1Z61vMm0J5Vjn2sNQq87FgaLbAAt8P4or
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NyWC6xVK2tlvtjcx0xv8I4O_bI0KebdS
# To: /content/GRU_TIME.xlsx
# 100% 10.3k/10.3k [00:00<00:00, 22.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1UFgEoC6-313M_dpjq7mW9LICaUvbkoNa
# To: /content/GRU_FORECASTRMse.xlsx
# 100% 6.50k/6.50k [00:00<00:00, 23.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1vuERyAz3ckNgg_vAAcjznPa7jpNJN9Rt
# To: /content/GRU_FORECASTMpe.xlsx
# 100% 6.54k/6.54k [00:00<00:00, 15.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZumVvaJpYdkWhSKZNlqbrHzi--A3iwtx
# To: /content/GRU_FORECASTMae.xlsx
# 100% 6.52k/6.52k [00:00<00:00, 16.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1z0qcyj5D7XoZ4bTMDZ3yaOuHaFaqmXSZ
# To: /content/RNN-LSTM_TIME.xlsx
# 100% 10.3k/10.3k [00:00<00:00, 30.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=16dF5YhHT4R_g5HbdAsO_cEXejJQ87Pg2
# To: /content/RNN-LSTM_FORECASTRMse.xlsx
# ...

# %%
df1 = pd.read_excel('/content/RNN_TIME.xlsx')
df2 = pd.read_excel('/content/LSTM_TIME.xlsx')
df3 = pd.read_excel('/content/GRU_TIME.xlsx')
df4 = pd.read_excel('/content/RNN-LSTM_TIME.xlsx')
df5 = pd.read_excel('/content/RNN-GRU_TIME.xlsx')
df6 = pd.read_excel('/content/LSTM-RNN_TIME.xlsx')
df7 = pd.read_excel('/content/GRU-RNN_TIME.xlsx')
df8 = pd.read_excel('/content/LSTM-GRU_TIME.xlsx')
df9 = pd.read_excel('/content/GRU-LSTM_TIME.xlsx')
df = pd.DataFrame()
df['RNN'] = df1[0]
df['LSTM'] = df2[0]
df['GRU'] = df3[0]
df['RNN_LSTM'] = df4[0]
df['RNN_GRU'] = df5[0]
df['LSTM_RNN'] = df6[0]
df['GRU_RNN'] = df7[0]
df['LSTM_GRU'] = df8[0]
df['GRU_LSTM'] = df9[0]

# %%
# Calculate the average time for each model
average_times = df.mean()
# Create a bar chart
plt.figure(figsize=(20, 12))
average_times.plot(kind='bar', color='skyblue')
#plt.title('Comparison of Computational Time Across Different Models')
plt.xlabel('Models' , fontsize=22)
plt.ylabel('Average Time (s)' , fontsize=22)
plt.xticks(fontsize = 18, rotation=0)
plt.yticks(fontsize = 18)
plt.tight_layout()
# Display the average times on top of the bars
for i, v in enumerate(average_times):
  plt.text(i, v, f"{v:.2f}", ha='center', va='bottom',  fontsize=18)
plt.savefig(folder_path + 'Comparison_Time_Dataset2-revisi.pdf', dpi=300)

plt.show()
